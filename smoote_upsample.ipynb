# %% [markdown]
# <h1>SMOTE</h1>
#
# synthetic Minorityy Oversampling Technique
#
# Smote involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
X,y = make_classification(
    random_state=42, 
    n_samples = 1000, 
    n_features=2,
    n_redundant=0,
    )

# %% [markdown]
# Way 1: count unique values in numpy

# %%
# count y values of how many of each class
values, count = np.unique(y, return_counts=True)
a = zip(values, count)
dict(a)
# Out:
# {np.int64(0): np.int64(498), np.int64(1): np.int64(502)}

# %% [markdown]
# Way 2: count unique values using numpy and python

# %%
import collections
counter = collections.Counter(y)
counter
# Out:
# Counter({np.int64(1): 502, np.int64(0): 498})

# %% [markdown]
# But we need to make an imbalance dataset

# %%
X,y = make_classification(
    random_state=42, 
    n_samples = 1000, 
    n_features=2,
    n_redundant=0,
    n_clusters_per_class=1,
    weights=[0.9, 0.1]  # Adjust weights to create imbalance
    )

# %%
values, count = np.unique(y, return_counts=True)
a = zip(values, count)
dict(a)
# Out:
# {np.int64(0): np.int64(895), np.int64(1): np.int64(105)}

# %% [markdown]
# Creating dataframe form those values

# %%
df1 = pd.DataFrame(X, columns=['feature1', 'feature2'])
df1['target'] = y
df1
# Out:
#      feature1  feature2  target
# 0    1.073546 -1.101339       0
# 1    0.755945 -1.172352       0
# 2    1.354479 -0.948528       0
# 3    3.103090  0.233485       0
# 4    1.951888 -0.270157       0
# ..        ...       ...     ...
# 995  1.713939  0.451639       1
# 996  1.509473 -0.794996       0
# 997 -2.150901 -2.989372       0
# 998  2.451647 -0.156629       0
# 999  3.641478  0.756925       0
#
# [1000 rows x 3 columns]

# %% [markdown]
# plotting the dataframe using matplotlib

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1], c=y, cmap='coolwarm')

# %% [markdown]
# Plotting using pandas

# %%
df1.plot.scatter(x='feature1', y='feature2', c='target', cmap='coolwarm')
plt.title('Scatter plot of features with target classes')
# Out:
# Text(0.5, 1.0, 'Scatter plot of features with target classes')

# %%
df1.target.value_counts().plot(kind='bar', color='skyblue')
plt.title('Count of target classes')
# Out:
# Text(0.5, 1.0, 'Count of target classes')

# %%
# %pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imbalanced-learn->imblearn) (2.0.1)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imbalanced-learn->imblearn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\useras\anaconda3\envs\cudaenv\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
df1.columns
# Out:
# Index(['feature1', 'feature2', 'target'], dtype='object')

# %%
oversampler = SMOTE(random_state=42)
X,y = oversampler.fit_resample(df1[['feature1', 'feature2']], df1['target'])

# %%
X.shape, y.shape
# Out:
# ((1790, 2), (1790,))

# %%
y.value_counts().reset_index()
import seaborn as sns
sns.barplot(
    x='target', 
    y='count', 
    data=y.value_counts().reset_index(), 
    hue='target',
    palette='coolwarm'
)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# Now we have similar count

# %%
df2 = pd.DataFrame(X, columns=['feature1', 'feature2'])
df2['target'] = y
df2
# Out:
#       feature1  feature2  target
# 0     1.073546 -1.101339       0
# 1     0.755945 -1.172352       0
# 2     1.354479 -0.948528       0
# 3     3.103090  0.233485       0
# 4     1.951888 -0.270157       0
# ...        ...       ...     ...
# 1785 -0.887867  2.567409       1
# 1786  1.333479  0.259539       1
# 1787  2.401345 -0.181753       1
# 1788  1.494385  0.491328       1
# 1789 -1.138164  2.728458       1
#
# [1790 rows x 3 columns]

# %%
plt.subplot(1,2,1)
plt.scatter(df2['feature1'], df2['feature2'],c=df2['target'], cmap='coolwarm')
plt.title('After SMOTE Oversampling')

plt.subplot(1,2,2)
plt.scatter(df1['feature1'], df1['feature2'],c=df1['target'], cmap='coolwarm')
plt.title('Before SMOTE Oversampling')
plt.tight_layout()
